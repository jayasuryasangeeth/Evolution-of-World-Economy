# %%
import pandas as pd
import plotly.graph_objects as go
import pandas as pd

# %%
# !pip3 install dash
# Out:
# ...
# [notice] A new release of pip available: 22.3 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df = pd.read_csv(r"C:\Users\mraka\Downloads\exports_percent_of_gdp.csv")

# %%
df.head()
# Out:
#                 country  1959  1960  1961  1962  1963  1964  1965  1966  1967  \
# 0                 Aruba   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1           Afghanistan  4.13  4.45  4.88  9.17  8.89  11.3  8.57  6.77   8.9
# 2                Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3               Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  United Arab Emirates   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    ...  2010   2011   2012  2013   2014   2015  2016  2017  2018  2019
# 0  ...  67.8   65.2   76.5  78.3   72.9   71.8  72.5  73.8   NaN   NaN
# 1  ...   NaN    NaN    NaN   NaN    NaN    NaN   NaN   NaN   NaN   NaN
# 2  ...  60.7   55.9   50.7  44.7   29.8   28.1  29.0  40.8  39.3  37.8
# 3  ...  29.2   28.9   28.9  28.2   27.3   29.0  31.6  31.6  31.3  23.1
# 4  ...  90.1  100.0  101.0  99.6  101.0  101.0  99.6  93.0  96.8   NaN
#
# [5 rows x 62 columns]

# %%
df = pd.melt(df,id_vars=['country'])

# %%
df
# Out:
#                     country variable  value
# 0                     Aruba     1959    NaN
# 1               Afghanistan     1959   4.13
# 2                    Angola     1959    NaN
# 3                   Albania     1959    NaN
# 4      United Arab Emirates     1959    NaN
# ...                     ...      ...    ...
# 12012                 Samoa     2019  31.60
# 12013                 Yemen     2019    NaN
# 12014          South Africa     2019  27.80
# 12015                Zambia     2019  46.80
# 12016              Zimbabwe     2019  37.20
#
# [12017 rows x 3 columns]

# %%
df.dropna(inplace =True)

# %%
df
# Out:
#             country variable  value
# 1       Afghanistan     1959   4.13
# 5         Argentina     1959   7.60
# 9         Australia     1959  13.00
# 12          Burundi     1959  12.50
# 14            Benin     1959   6.12
# ...             ...      ...    ...
# 12011       Vanuatu     2019  17.80
# 12012         Samoa     2019  31.60
# 12014  South Africa     2019  27.80
# 12015        Zambia     2019  46.80
# 12016      Zimbabwe     2019  37.20
#
# [8376 rows x 3 columns]

# %%
 df.rename(columns = {'variable': 'year','value':'GDP'},inplace=True)

# %%
df
# Out:
#             country  year    GDP
# 1       Afghanistan  1959   4.13
# 5         Argentina  1959   7.60
# 9         Australia  1959  13.00
# 12          Burundi  1959  12.50
# 14            Benin  1959   6.12
# ...             ...   ...    ...
# 12011       Vanuatu  2019  17.80
# 12012         Samoa  2019  31.60
# 12014  South Africa  2019  27.80
# 12015        Zambia  2019  46.80
# 12016      Zimbabwe  2019  37.20
#
# [8376 rows x 3 columns]

# %%
df.to_csv(r'C:\Users\mraka\Downloads\export_GDP.csv', encoding='utf-8')

# %%
gdp_data = df

# %%
# !pip3 install --upgrade pip wheel setuptools requests
# Out:
# ...
#   Using cached pip-23.0.1-py3-none-any.whl (2.1 MB)
# ...
#   Using cached setuptools-67.5.1-py3-none-any.whl (1.1 MB)
# ...
# ERROR: To modify pip, please run the following command:
# C:\Python311\python.exe -m pip install --upgrade pip wheel setuptools requests
#
# [notice] A new release of pip available: 22.3 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import plotly.graph_objs as go
import plotly.express as px

# %%
import plotly.express as px

fig = px.choropleth(df, locations="country", locationmode="country names", color="GDP",
                    animation_frame="year", range_color=[0, 70],
                    projection="natural earth", color_continuous_scale="Viridis")
fig.update_layout(title_text="Your Title", geo=dict(showframe=False, showcoastlines=False),
                  width=1000, height=600)
fig.show()

# %%
fig.write_html('map.html')

# %%
dict_df1 = pd.read_excel(r"C:\Users\mraka\Downloads\Table.xlsx", 
                   sheet_name=['2020','2021','2022'])

# %%
df_2020 = dict_df1 .get('2020')
df_2021 = dict_df1 .get('2021')
df_2022 = dict_df1 .get('2022')

# %%
df_2020
# Out:
#     s.no                                           Industry  year       Q1  \
# 0      1                                     All industries  2020  37584.4
# 1      2                                 Private industries  2020  33411.7
# 2      3        Agriculture, forestry, fishing, and hunting  2020    459.7
# 3      4                                              Farms  2020    406.1
# 4      5          Forestry, fishing, and related activities  2020     53.6
# ..   ...                                                ...   ...      ...
# 94    95                                    State and local  2020   2901.7
# 95    96                                 General government  2020   2542.5
# 96    97                             Government enterprises  2020    359.2
# 97    98                Private goods-producing industries1  2020   8580.9
# 98    99              Private services-producing industr...  2020  24830.8
#
#          Q2       Q3       Q4
# 0   34056.5  36755.8  37851.3
# ...

# %%
df_2021
# Out:
#     s.no                                           Industry  year       Q1  \
# 0    1.0                                     All industries  2021  39371.3
# 1    2.0                                 Private industries  2021  35006.8
# 2    3.0        Agriculture, forestry, fishing, and hunting  2021    478.6
# 3    4.0                                              Farms  2021    420.6
# 4    5.0          Forestry, fishing, and related activities  2021     58.1
# ..   ...                                                ...   ...      ...
# 95  96.0                                 General government  2021   2589.2
# 96  97.0                             Government enterprises  2021    353.1
# 97   NaN                                           Addenda:  2021      NaN
# 98  98.0                Private goods-producing industries1  2021   8892.7
# 99  99.0              Private services-producing industr...  2021  26114.1
#
#          Q2       Q3       Q4
# 0   40874.4  42080.3  43293.0
# ...

# %%
df_2022
# Out:
#     s.no                                           Industry  year       Q1  \
# 0      1                                     All industries  2022  44579.4
# 1      2                                 Private industries  2022  39908.4
# 2      3        Agriculture, forestry, fishing, and hunting  2022    598.1
# 3      4                                              Farms  2022    533.7
# 4      5          Forestry, fishing, and related activities  2022     64.4
# ..   ...                                                ...   ...      ...
# 94    95                                    State and local  2022   3250.6
# 95    96                                 General government  2022   2839.0
# 96    97                             Government enterprises  2022    411.7
# 97    98                Private goods-producing industries1  2022  10459.9
# 98    99              Private services-producing industr...  2022  29448.5
#
#          Q2       Q3
# 0   45972.9  46562.9
# 1   41156.8  41675.7
# ...

# %%
pdList = [df_2020,df_2021,df_2022]  # List of your dataframes
new_df = pd.concat(pdList)

# %%
new_df
# Out:
#     s.no                                           Industry  year       Q1  \
# 0    1.0                                     All industries  2020  37584.4
# 1    2.0                                 Private industries  2020  33411.7
# 2    3.0        Agriculture, forestry, fishing, and hunting  2020    459.7
# 3    4.0                                              Farms  2020    406.1
# 4    5.0          Forestry, fishing, and related activities  2020     53.6
# ..   ...                                                ...   ...      ...
# 94  95.0                                    State and local  2022   3250.6
# 95  96.0                                 General government  2022   2839.0
# 96  97.0                             Government enterprises  2022    411.7
# 97  98.0                Private goods-producing industries1  2022  10459.9
# 98  99.0              Private services-producing industr...  2022  29448.5
#
#          Q2       Q3       Q4
# 0   34056.5  36755.8  37851.3
# ...

# %%
new_df = pd.melt(new_df,id_vars=['Industry','year','s.no'])

# %%
new_df
# Out:
#                                                Industry  year  s.no variable  \
# 0                                        All industries  2020   1.0       Q1
# 1                                    Private industries  2020   2.0       Q1
# 2           Agriculture, forestry, fishing, and hunting  2020   3.0       Q1
# 3                                                 Farms  2020   4.0       Q1
# 4             Forestry, fishing, and related activities  2020   5.0       Q1
# ...                                                 ...   ...   ...      ...
# 1187                                    State and local  2022  95.0       Q4
# 1188                                 General government  2022  96.0       Q4
# 1189                             Government enterprises  2022  97.0       Q4
# 1190                Private goods-producing industries1  2022  98.0       Q4
# 1191              Private services-producing industr...  2022  99.0       Q4
#
#         value
# 0     37584.4
# ...

# %%
new_df.rename(columns = {'variable': 'Quarter','value':'GDP'},inplace=True)

# %%
new_df
# Out:
#                                                Industry  year  s.no Quarter  \
# 0                                        All industries  2020   1.0      Q1
# 1                                    Private industries  2020   2.0      Q1
# 2           Agriculture, forestry, fishing, and hunting  2020   3.0      Q1
# 3                                                 Farms  2020   4.0      Q1
# 4             Forestry, fishing, and related activities  2020   5.0      Q1
# ...                                                 ...   ...   ...     ...
# 1187                                    State and local  2022  95.0      Q4
# 1188                                 General government  2022  96.0      Q4
# 1189                             Government enterprises  2022  97.0      Q4
# 1190                Private goods-producing industries1  2022  98.0      Q4
# 1191              Private services-producing industr...  2022  99.0      Q4
#
#           GDP
# 0     37584.4
# 1     33411.7
# ...

# %%
import pandas as pd

new_df["Period"] = new_df.apply(lambda row: f"{row['year']} {row['Quarter']}", axis=1)

# %%
new_df
# Out:
#                                                Industry  year  s.no Quarter  \
# 0                                        All industries  2020   1.0      Q1
# 1                                    Private industries  2020   2.0      Q1
# 2           Agriculture, forestry, fishing, and hunting  2020   3.0      Q1
# 3                                                 Farms  2020   4.0      Q1
# 4             Forestry, fishing, and related activities  2020   5.0      Q1
# ...                                                 ...   ...   ...     ...
# 1187                                    State and local  2022  95.0      Q4
# 1188                                 General government  2022  96.0      Q4
# 1189                             Government enterprises  2022  97.0      Q4
# 1190                Private goods-producing industries1  2022  98.0      Q4
# 1191              Private services-producing industr...  2022  99.0      Q4
#
#           GDP   Period
# 0     37584.4  2020 Q1
# ...

# %%
new_df.to_csv(r"C:\Users\mraka\Downloads\output1.xlsx")

# %% [markdown]
# python to plotly website

# %%
import chart_studio
import chart_studio.plotly as py
import chart_studio.tools as tls

username = 'akashganesan'
api_key = '9rKgb8tf7EepXpXBRNAg'
chart_studio.tools.set_credentials_file(username=username,api_key=api_key)

# %%
fig = px.choropleth(df, locations="country", locationmode="country names", color="GDP",
                    animation_frame="year", range_color=[0, 70],
                    projection="natural earth", color_continuous_scale="Viridis")
fig.update_layout(title_text="Export and Import", geo=dict(showframe=False, showcoastlines=False),
                  width=800, height=600)
fig.show()

# %%
py.plot(fig, filename ='compviz_industry',auto_open = False)
# Out:
# 'https://plotly.com/~akashganesan/1/'

# %% [markdown]
# Agriculture sector data

# %%
df_agri = pd.read_csv(r"C:\Users\mraka\Downloads\agriculture_percent_of_gdp.csv")

# %%
df_agri
# Out:
#                   country  1959  1960  1961  1962  1963   1964   1965   1966  \
# 0                   Aruba   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN
# 1             Afghanistan   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN
# 2                  Angola   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN
# 3                 Albania   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN
# 4    United Arab Emirates   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN
# ..                    ...   ...   ...   ...   ...   ...    ...    ...    ...
# 200                 Samoa   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN
# 201                 Yemen   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN
# 202          South Africa  10.7  11.0  10.6  10.4   9.0   8.76   9.05   9.97
# 203                Zambia  11.5  12.8  12.3  13.0  12.0  14.30  13.40  12.80
# 204              Zimbabwe   NaN   NaN   NaN   NaN   NaN  18.80  21.10  21.90
#
# ...

# %%
df_agri = pd.melt(df_agri,id_vars=['country'])

# %%
df_agri
# Out:
#                     country variable  value
# 0                     Aruba     1959    NaN
# 1               Afghanistan     1959    NaN
# 2                    Angola     1959    NaN
# 3                   Albania     1959    NaN
# 4      United Arab Emirates     1959    NaN
# ...                     ...      ...    ...
# 12500                 Samoa     2019  10.30
# 12501                 Yemen     2019   5.00
# 12502          South Africa     2019   2.53
# 12503                Zambia     2019   2.98
# 12504              Zimbabwe     2019   7.61
#
# [12505 rows x 3 columns]

# %%
df_agri.rename(columns = {'variable': 'year','value':'GDP'},inplace=True)

# %%
 df_agri
# Out:
#                     country  year    GDP
# 0                     Aruba  1959    NaN
# 1               Afghanistan  1959    NaN
# 2                    Angola  1959    NaN
# 3                   Albania  1959    NaN
# 4      United Arab Emirates  1959    NaN
# ...                     ...   ...    ...
# 12500                 Samoa  2019  10.30
# 12501                 Yemen  2019   5.00
# 12502          South Africa  2019   2.53
# 12503                Zambia  2019   2.98
# 12504              Zimbabwe  2019   7.61
#
# [12505 rows x 3 columns]

# %%
df_agri.dropna(inplace =True)

# %%
df_agri
# Out:
#             country  year    GDP
# 13            Benin  1959  46.20
# 14     Burkina Faso  1959  38.50
# 15       Bangladesh  1959  57.50
# 24           Brazil  1959  15.70
# 28         Botswana  1959  43.20
# ...             ...   ...    ...
# 12500         Samoa  2019  10.30
# 12501         Yemen  2019   5.00
# 12502  South Africa  2019   2.53
# 12503        Zambia  2019   2.98
# 12504      Zimbabwe  2019   7.61
#
# [8089 rows x 3 columns]

# %%
fig = px.choropleth(df_agri, locations="country", locationmode="country names", color="GDP",
                    animation_frame="year", range_color=[0, 70],
                    projection="natural earth", color_continuous_scale="Viridis")
fig.update_layout(title_text="Agriculture Industry", geo=dict(showframe=False, showcoastlines=False),
                  width=800, height=600)
fig.show()

# %%
py.plot(fig, filename ='compviz_agri_industry',auto_open = False)
# Out:
# 'https://plotly.com/~akashganesan/5/'

# %% [markdown]
# Service Industry

# %%
df_service = pd.read_csv(r"C:\Users\mraka\Downloads\services_percent_of_gdp.csv")

# %%
df_service
# Out:
#                   country  1959  1960  1961  1962  1963  1964  1965  1966  \
# 0                   Aruba   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1             Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2                  Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3                 Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4    United Arab Emirates   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..                    ...   ...   ...   ...   ...   ...   ...   ...   ...
# 195                 Samoa   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 196                 Yemen   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 197          South Africa  48.4  48.2  48.6  48.6  48.8  48.5  48.7  49.4
# 198                Zambia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 199              Zimbabwe   NaN   NaN   NaN   NaN  95.0  46.7  48.1  45.6
#
#      1967  ...  2010  2011  2012  2013  2014  2015  2016  2017  2018  2019
# ...

# %%
df_service = pd.melt(df_service,id_vars=['country'])

# %%
df_service.rename(columns = {'variable': 'year','value':'GDP'},inplace=True)

# %%
df_service.dropna(inplace =True)

# %%
df_service
# Out:
#             country  year   GDP
# 13            Benin  1959  43.6
# 14     Burkina Faso  1959  38.3
# 15       Bangladesh  1959  35.6
# 24           Brazil  1959  32.3
# 28         Botswana  1959  43.1
# ...             ...   ...   ...
# 12195         Samoa  2019  74.9
# 12196         Yemen  2019  16.8
# 12197  South Africa  2019  64.6
# 12198        Zambia  2019  53.6
# 12199      Zimbabwe  2019  49.9
#
# [7547 rows x 3 columns]

# %%
fig = px.choropleth(df_service, locations="country", locationmode="country names", color="GDP",
                    animation_frame="year", range_color=[0, 70],
                    projection="natural earth", color_continuous_scale="Viridis")
fig.update_layout(title_text="Agriculture Industry", geo=dict(showframe=False, showcoastlines=False),
                  width=800, height=600)
fig.show()

# %%
py.plot(fig, filename ='compviz_service_industry',auto_open = False)
# Out:
# 'https://plotly.com/~akashganesan/12/'

# %% [markdown]
# Inflation data

# %%
df_inflation = pd.read_csv(r"C:\Users\mraka\Downloads\inflation_annual_percent.csv")

# %%
df_inflation
# Out:
#           country   1960   1961   1962  1963  1964   1965   1966  1967  1968  \
# 0           Aruba    NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN   NaN
# 1     Afghanistan    NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN   NaN
# 2          Angola    NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN   NaN
# 3         Albania    NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN   NaN
# 4         Andorra    NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN   NaN
# ..            ...    ...    ...    ...   ...   ...    ...    ...   ...   ...
# 207         Samoa    NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN   NaN
# 208         Yemen    NaN    NaN    NaN   NaN   NaN    NaN    NaN   NaN   NaN
# 209  South Africa   1.35  0.383   3.27  1.99  2.95   4.37   4.03   3.8  7.59
# 210        Zambia  −3.66   2.09  0.404  4.08  10.6   23.6  0.263  15.9  22.9
# 211      Zimbabwe  −2.04   0.47  −2.35  6.14   2.7  −3.73  0.577  3.87  5.08
#
# ...

# %%
df_inflation = pd.melt(df_inflation,id_vars=['country'])

# %%
df_inflation
# Out:
#             country variable  value
# 0             Aruba     1960    NaN
# 1       Afghanistan     1960    NaN
# 2            Angola     1960    NaN
# 3           Albania     1960    NaN
# 4           Andorra     1960    NaN
# ...             ...      ...    ...
# 12715         Samoa     2019  0.215
# 12716         Yemen     2019    NaN
# 12717  South Africa     2019   5.27
# 12718        Zambia     2019   13.7
# 12719      Zimbabwe     2019    559
#
# [12720 rows x 3 columns]

# %%
df_region = pd.read_csv(r"C:\Users\mraka\Downloads\region.csv")

# %%
df_region
# Out:
#                     country   region          sub-region
# 0               Afghanistan     Asia       Southern Asia
# 1                    Angola   Africa  Sub-Saharan Africa
# 2                   Albania   Europe     Southern Europe
# 3                   Andorra   Europe     Southern Europe
# 4      United Arab Emirates     Asia        Western Asia
# ...                     ...      ...                 ...
# 48940                 Samoa  Oceania           Polynesia
# 48941                 Yemen     Asia        Western Asia
# 48942          South Africa   Africa  Sub-Saharan Africa
# 48943                Zambia   Africa  Sub-Saharan Africa
# 48944              Zimbabwe   Africa  Sub-Saharan Africa
#
# [48945 rows x 3 columns]

# %%
merged_df = pd.merge(df_inflation, df_region, on='country', how='left')

# %%
merged_df
# Out:
#              country variable value  region          sub-region
# 0              Aruba     1960   NaN     NaN                 NaN
# 1        Afghanistan     1960   NaN    Asia       Southern Asia
# 2        Afghanistan     1960   NaN    Asia       Southern Asia
# 3        Afghanistan     1960   NaN    Asia       Southern Asia
# 4        Afghanistan     1960   NaN    Asia       Southern Asia
# ...              ...      ...   ...     ...                 ...
# 2907715     Zimbabwe     2019   559  Africa  Sub-Saharan Africa
# 2907716     Zimbabwe     2019   559  Africa  Sub-Saharan Africa
# 2907717     Zimbabwe     2019   559  Africa  Sub-Saharan Africa
# 2907718     Zimbabwe     2019   559  Africa  Sub-Saharan Africa
# 2907719     Zimbabwe     2019   559  Africa  Sub-Saharan Africa
#
# [2907720 rows x 5 columns]

# %%
merged_df.dropna(inplace =True)

# %%
merged_df
# Out:
#              country variable value  region          sub-region
# 10542    Afghanistan     2002  11.7    Asia       Southern Asia
# 10543    Afghanistan     2002  11.7    Asia       Southern Asia
# 10544    Afghanistan     2002  11.7    Asia       Southern Asia
# 10545    Afghanistan     2002  11.7    Asia       Southern Asia
# 10546    Afghanistan     2002  11.7    Asia       Southern Asia
# ...              ...      ...   ...     ...                 ...
# 2906575     Zimbabwe     2019   559  Africa  Sub-Saharan Africa
# 2906576     Zimbabwe     2019   559  Africa  Sub-Saharan Africa
# 2906577     Zimbabwe     2019   559  Africa  Sub-Saharan Africa
# 2906578     Zimbabwe     2019   559  Africa  Sub-Saharan Africa
# 2906579     Zimbabwe     2019   559  Africa  Sub-Saharan Africa
#
# [2092336 rows x 5 columns]

# %%
merged_df = merged_df.drop_duplicates()

# %%
merged_df
# Out:
#               country variable  value   region          sub-region
# 0               Aruba     1960    NaN      NaN                 NaN
# 1         Afghanistan     1960    NaN     Asia       Southern Asia
# 252            Angola     1960    NaN   Africa  Sub-Saharan Africa
# 503           Albania     1960    NaN   Europe     Southern Europe
# 754           Andorra     1960    NaN   Europe     Southern Europe
# ...               ...      ...    ...      ...                 ...
# 2906465         Samoa     2019  0.215  Oceania           Polynesia
# 2906716         Yemen     2019    NaN     Asia        Western Asia
# 2906967  South Africa     2019   5.27   Africa  Sub-Saharan Africa
# 2907218        Zambia     2019   13.7   Africa  Sub-Saharan Africa
# 2907469      Zimbabwe     2019    559   Africa  Sub-Saharan Africa
#
# [12720 rows x 5 columns]

# %%
merged_df.dropna(inplace =True)
# Out:
# C:\Users\mraka\AppData\Local\Temp\ipykernel_19320\3335276848.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
merged_df
# Out:
#               country variable  value    region  \
# 1256        Argentina     1960   20.3  Americas
# 2010        Australia     1960   3.22   Oceania
# 2261          Austria     1960   5.09    Europe
# 2763          Burundi     1960   20.1    Africa
# 3014          Belgium     1960   1.32    Europe
# ...               ...      ...    ...       ...
# 2906214       Vanuatu     2019    1.8   Oceania
# 2906465         Samoa     2019  0.215   Oceania
# 2906967  South Africa     2019   5.27    Africa
# 2907218        Zambia     2019   13.7    Africa
# 2907469      Zimbabwe     2019    559    Africa
#
#                               sub-region
# 1256     Latin America and the Caribbean
# 2010           Australia and New Zealand
# 2261                      Western Europe
# 2763                  Sub-Saharan Africa
# 3014                      Western Europe
# ...                                  ...
# 2906214                        Melanesia
# 2906465                        Polynesia
# ...

# %%
table = pd.pivot_table(merged_df, values='value', index=['country', 'variable'],
                    columns=['region'])
# Out:
# C:\Users\mraka\AppData\Local\Temp\ipykernel_19320\1493500787.py:1: FutureWarning:
#
# pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.

# %%
table
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
merged_df.to_csv(r'C:\Users\mraka\Downloads\inflation.csv', encoding='utf-8')
